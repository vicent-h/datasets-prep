# %%
with open('out/analise_textos.tsv', 'r') as f:
    for i in range(10):  # primeiras 10 linhas
        print(f.readline())
# Out:
# European Medicines Agency<SEP>European Medicines Agency
#
# EMEA/ H/ C/ 471<SEP>EMEA/ H/ C/ 471
#
# EUROPEAN PUBLIC ASSESSMENT REPORT (EPAR)<SEP>INFORME PÚBLICO EUROPEO DE EVALUACIÓN (EPAR)
#
# ABILIFY<SEP>ABILIFY
#
# EPAR summary for the public<SEP>Resumen del EPAR para el público general
#
# This document is a summary of the European Public Assessment Report (EPAR).<SEP>En el presente documento se resume el Informe Público Europeo de Evaluación (EPAR).
#
# It explains how the Committee for Medicinal Products for Human Use (CHMP) assessed the studies performed, to reach their recommendations on how to use the medicine.<SEP>En él se explica cómo el Comité de Medicamentos de Uso Humano (CHMP) ha evaluado los estudios realizados con el medicamento a fin de emitir unas recomendaciones sobre su uso.
#
# ...

# %%
import pandas as pd

df_analise =
