# %%
with open('/media/alvarinho/dados/Datasets/refined/analise_textos.tsv', 'r') as f:
    for i in range(10):  # primeiras 10 linhas
        print(f.readline())
# Out:
# 16 Percentage of subjects with antibody titres ≥ assay cut-off one month after booster vaccination with Infanrix hexa<SEP>Porcentaje de sujetos con títulos de anticuerpos ≥ punto de corte en los ensayos clínicos un mes después de la vacunación de recuerdo con Infanrix hexa
#
# Antibody<SEP>Anticuerpo
#
# Booster vaccination at 11<SEP>Vacunación de recuerdo a los
#
# Booster vaccination during the<SEP>Vacunación de recuerdo durante
#
# second year of life following a three dose primary course N= 2009%<SEP>el segundo año de vida después de un ciclo de vacunación primaria de tres dosis N= 2009%
#
# Anti-Polio type 2 (1/ 8 dilution) †<SEP>Anti-Polio tipo 2 (dilución 1/ 8) †
#
# Anti-Polio type 3 (1/ 8 dilution) †<SEP>Anti-Polio tipo 3 (dilución 1/ 8) †
#
# Anti-PRP (0.15 μ g/ ml) † N = number of subjects<SEP>Anti-PRP (0,15 μ g/ ml) † N = número de sujetos
#
# † cut-off accepted as indicative of protection<SEP>† punto de corte aceptado como indicativo de protección
#
# ...

# %%
import pandas as pd

df_analise =
